# %%
# %pip install seaborn 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %pip install openpyxl
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df=pd.read_excel('emp_data.xlsx')

# %%
df=pd.DataFrame(df)
df
# Out:
#        employee_id         department     region  education gender  \
# 0            74430                 HR   region_4  Bachelors      f
# 1            72255  Sales & Marketing  region_13  Bachelors      m
# 2            38562        Procurement   region_2  Bachelors      f
# 3            64486            Finance  region_29  Bachelors      m
# 4            46232        Procurement   region_7  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 15419        64573         Technology   region_7  Bachelors      f
# 15420        49584                 HR   region_7  Bachelors      m
# 15421        49584                 HR   region_7  Bachelors      m
# 15422        49584                 HR   region_7  Bachelors      m
# 15423        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                   other                1   31                     3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15424 entries, 0 to 15423
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            15424 non-null  int64
#  1   department             15424 non-null  object
#  2   region                 15424 non-null  object
#  3   education              15424 non-null  object
#  4   gender                 15424 non-null  object
#  5   recruitment_channel    15424 non-null  object
#  6   no_of_trainings        15424 non-null  int64
#  7   age                    15424 non-null  int64
#  8   previous_year_rating   15424 non-null  int64
#  9   length_of_service      15424 non-null  int64
#  10  KPIs_met_more_than_80  15424 non-null  int64
#  11  awards_won             15424 non-null  int64
#  12  avg_training_score     15424 non-null  int64
# dtypes: int64(8), object(5)
# memory usage: 1.2+ MB

# %%
# Count of employees per department

plt.figure(figsize=(6, 3))
sns.countplot(data=df, x="department", order=df["department"].value_counts().index,color='brown')
plt.xticks(rotation=45)
plt.title("Employee Count by Department")
plt.show()

# %%
#Employee counts by Length of Services

sns.histplot(df['length_of_service'],bins=20,kde=True,color="green")
plt.title("Counts Of Employee By Length of services")
plt.ylabel("Count Of Employees")
plt.show()

# %%
#Awards Won by Departments

awd=df[df['awards_won']==1]
awards_won_dept=awd.groupby('department')['awards_won'].sum().plot(kind='pie')
plt.title("Awards won by Deparments")
# Out:
# Text(0.5, 1.0, 'Awards won by Deparments')

# %%
#Gender Distribution based on KPIs met more than 80


plt.figure(figsize=(6,5))
kpi=df[df['KPIs_met_more_than_80']==1]
gender_kpi=kpi.groupby('gender')['KPIs_met_more_than_80'].count().plot(kind='barh')
plt.xlabel('Count of KPIs_met_more_than_80')
plt.title("KPIs_met_more_than_80 by Gender Distribution")
plt.show()

# %%
# Average training score per department

dept_training = df.groupby("department")["avg_training_score"].mean().sort_values()
plt.figure(figsize=(6, 4))
sns.barplot(x=dept_training.index, y=dept_training.values, palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Average Training Score by Department")
plt.show()
# Out:
# <ipython-input-19-b65a4dd37315>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dept_training.index, y=dept_training.values, palette="coolwarm")

# %%
# Distribution of Age

plt.figure(figsize=(6,4))
sns.histplot(df['age'], bins=20, kde=True, color="Purple")
plt.title("Age Distribution")
plt.show()
